# %%
# --- Colab: Upload all PDFs from a Drive folder to S3 by county (CA) ---

# !pip -q install boto3

import os, re, unicodedata, pathlib
from typing import Optional, Tuple
import boto3
from botocore.config import Config
from botocore.exceptions import ClientError

# 1) Mount Google Drive (you'll be prompted to authorize)
from google.colab import drive
drive.mount("/content/drive")
DRY_RUN =False
# 2) === EDIT THESE ===
# Google Drive folder that contains your PDF files
DRIVE_FOLDER = "/content/drive/MyDrive/municode_downloads_GA"  # <-- change this

# AWS creds (TEMPORARY KEYS RECOMMENDED in Colab)
AWS_REGION = "us-east-1"
os.environ["AWS_ACCESS_KEY_ID"]     = ""     # <-- put your key
os.environ["AWS_SECRET_ACCESS_KEY"] = ""  # <-- put your secret

# S3 target info
BUCKET      = "berkeley-capstone-unbarred-2.0-data"
BASE_PREFIX = "env=prod/zone=raw/state=ga"  # fixed per your request

# ================== Helpers (GA version) ==================
STATE_ABBR = "ga"  # canonical two-letter code for output

def slugify(s: str) -> str:
    """
    Lowercase, normalize accents, replace non-alphanumerics with '-',
    collapse multiple hyphens, strip edges.
    """
    s = unicodedata.normalize("NFKD", s)
    s = "".join(ch for ch in s if not unicodedata.combining(ch))
    s = s.lower()
    s = re.sub(r"[^a-z0-9]+", "-", s)
    s = re.sub(r"-{2,}", "-", s).strip("-")
    return s

def parse_county_from_filename(filename: str) -> Optional[str]:
    """
    Accepts flexible GA filenames, e.g.:
      - "Fulton County, GA Code of Ordinances.pdf"
      - "DeKalb County, Georgia.PDF"
      - "St. Marys County, Ga.pdf"
      - "Macon-Bibb County, GA Code of Ordinances, Part A.pdf"
    Returns 'fulton-county', 'dekalb-county', etc., or None if no match.
    """
    name = pathlib.Path(filename).name
    base = re.sub(r"\.[Pp][Dd][Ff]$", "", name).strip()

    # Normalize small punctuation/spacing variants
    base = base.replace("_", " ")
    base = re.sub(r"\s{2,}", " ", base)

    # GA variants after 'County' (case-insensitive), with ANY trailing text allowed
    ga_suffix = r"(?:GA|Ga\.?|Georgia)"

    # Capture everything up to 'County' as the county name; require the state marker AFTER 'County'
    m = re.search(
        rf"""(?ix)
            ^\s*
            (?P<county>.+?)      # county words (e.g., 'Macon-Bibb', 'DeKalb', 'St. Marys')
            \s*County\b          # literal 'County'
            \s*,?\s*             # optional comma/space
            {ga_suffix}\b        # one of: GA | Ga | Ga. | Georgia
            .*                   # allow any trailing text (e.g., 'Code of Ordinances')
            $""",
        base,
    )
    if not m:
        return None

    county_words = m.group("county").strip()
    if not county_words:
        return None

    county_slug = slugify(county_words) + "-county"
    return county_slug

def dest_key_for(county_slug: str) -> str:
    """
    Build the destination S3 key.
    File name pattern: '<county-slug>-<state>.pdf' -> e.g., 'fulton-county-ga.pdf'
    Folder layout: '<BASE_PREFIX>/county=<county-slug>/<filename>'
    """
    filename = f"{county_slug}-{STATE_ABBR}.pdf"
    return f"{BASE_PREFIX}/county={county_slug}/{filename}"

# ================== S3 client and upload loop (uses GA helpers) ==================
cfg = Config(retries={"max_attempts": 10, "mode": "standard"})
s3  = boto3.client("s3", region_name=AWS_REGION, config=cfg)

def upload_pdf(local_path: str, key: str) -> bool:
    """Upload a local PDF to S3 with AES256 server-side encryption."""
    try:
        if DRY_RUN:
            print(f"[DRY-RUN] Would upload: {local_path} -> s3://{BUCKET}/{key}")
            return True
        s3.upload_file(
            Filename=local_path,
            Bucket=BUCKET,
            Key=key,
            ExtraArgs={"ServerSideEncryption": "AES256", "ContentType": "application/pdf"},
        )
        print(f"[OK] {local_path} -> s3://{BUCKET}/{key}")
        return True
    except ClientError as e:
        print(f"[ERROR] {local_path}: {e}")
        return False

# Find and upload all PDFs
pdf_paths = []
for p in pathlib.Path(DRIVE_FOLDER).glob("**/*.pdf"):
    pdf_paths.append(str(p))
for p in pathlib.Path(DRIVE_FOLDER).glob("**/*.PDF"):
    pdf_paths.append(str(p))

if not pdf_paths:
    raise SystemExit(f"No PDFs found under: {DRIVE_FOLDER}")

print(f"Found {len(pdf_paths)} PDF(s) under {DRIVE_FOLDER}")

uploaded, skipped = 0, 0
for local_path in sorted(set(pdf_paths)):
    county_slug = parse_county_from_filename(local_path)
    if not county_slug:
        print(f"[SKIP] Filename doesn't look like '<County> County, GA(EORGIA) ... .pdf': {local_path}")
        skipped += 1
        continue

    key = dest_key_for(county_slug)
    ok = upload_pdf(local_path, key)
    uploaded += int(ok)

print(f"\nDone. Uploaded: {uploaded}, Skipped: {skipped}")
print(f"S3 base prefix: s3://{BUCKET}/{BASE_PREFIX}/")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 109.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.3 MB/s eta 0:00:00
# Mounted at /content/drive
# Found 110 PDF(s) under /content/drive/MyDrive/municode_downloads_GA
# [OK] /content/drive/MyDrive/municode_downloads_GA/Augusta-Richmond County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=augusta-richmond-county/augusta-richmond-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Baldwin County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=baldwin-county/baldwin-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Banks County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=banks-county/banks-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Barrow County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=barrow-county/barrow-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Bartow County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=bartow-county/bartow-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Ben Hill County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=ben-hill-county/ben-hill-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Berrien County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=berrien-county/berrien-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Bleckley County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=bleckley-county/bleckley-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Brantley County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=brantley-county/brantley-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Brooks County, GA Code of Ordinance.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=brooks-county/brooks-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Bryan County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=bryan-county/bryan-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Bulloch County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=bulloch-county/bulloch-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Burke County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=burke-county/burke-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Butts County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=butts-county/butts-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Carroll County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=carroll-county/carroll-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Catoosa County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=catoosa-county/catoosa-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Cherokee County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=cherokee-county/cherokee-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Cobb County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=cobb-county/cobb-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Coffee County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=coffee-county/coffee-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Colquitt County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=colquitt-county/colquitt-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Columbia County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=columbia-county/columbia-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Cook County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=cook-county/cook-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Coweta County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=coweta-county/coweta-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Crisp County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=crisp-county/crisp-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Cusseta-Chattahoochee County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=cusseta-chattahoochee-county/cusseta-chattahoochee-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Dade County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=dade-county/dade-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Dawson County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=dawson-county/dawson-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/DeKalb County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=dekalb-county/dekalb-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Dodge County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=dodge-county/dodge-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Douglas County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=douglas-county/douglas-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Early County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=early-county/early-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Echols County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=echols-county/echols-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Effingham County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=effingham-county/effingham-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Elbert County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=elbert-county/elbert-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/Emanuel County, GA Code of Ordinances.pdf -> s3://berkeley-capstone-unbarred-2.0-data/env=prod/zone=raw/state=ga/county=emanuel-county/emanuel-county-ga.pdf
# [OK] /content/drive/MyDrive/municode_downloads_GA/